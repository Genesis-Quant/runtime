# %%
from core.workers import *
# Out:
# 2026-07-27 17:50:45 [SUCCESS] ts_api.py | <module>: 187行| Tushare Pro 初始化完成，共加载 5,871 只股票
# 2026-07-27 17:50:45 [ INFO  ] session.py | <module>: 10行| DolphinDB: 127.0.0.1:8848

# %%
start_date = "20100101"

# %%
StockDailyWorker(start_date=start_date).run()

# %%
StockLimitWorker(start_date=start_date).run()

# %%
StockDailyBasicWorker(start_date=start_date).run()

# %%
StockAdjFactorWorker(start_date=start_date).run()

# %%
StockHfqWorker(start_date=start_date).run()

# %%
StockBalanceSheetWorker(start_date=start_date).run()

# %%
StockIncomeWorker(start_date=start_date).run()

# %%
StockCashflowWorker(start_date=start_date).run()

# %%
StockFinaIndicatorWorker(start_date=start_date).run()

# %%
StockSTWorker(start_date=start_date).run()

# %%
IndexWeightWorker("000016.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000300.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000905.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000852.SH", start_date=start_date).run()

# %%
StockDividendWorker(start_date=start_date, overwrite=True).run()
# Out:
# 2026-07-27 09:22:22 [ DEBUG ] stock.py | __init__: 80行| <StockDividendWorker> 初始化：股票=5,871，2010-01-01 至 2026-07-27，threads=3，throttle=8，max_retries=3，batch_size=800000
# 2026-07-27 09:22:22 [ INFO  ] worker.py | run: 224行| <StockDividendWorker> 开始更新：2010-01-01 至 2026-07-27，字段=13，线程=3，限速=8次/秒，批量=800,000行
# 2026-07-27 09:22:23 [ DEBUG ] wide.py | open: 39行| <StockDividendWorker> 自定义表 Writer 已创建
# 2026-07-27 09:22:23 [ INFO  ] stock.py | fetch_all: 224行| <StockDividendWorker> 覆盖计划：首次=5,871，续更=0，已最新=0，待请求=5,871/5,871，实际起点=2010-01-01 至 2010-01-01，截止=2026-07-27
# 2026-07-27 09:22:26 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000035.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-27 09:22:31 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000155.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-27 09:22:33 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000410.SZ] 忽略 1 条日期不完整的分红记录
# ...

# %%
FundDailyWorker(start_date=start_date, overwrite=True).run()
# Out:
# 2026-07-27 17:50:50 [ DEBUG ] stock.py | __init__: 80行| <FundDailyWorker> 初始化：股票=73，2010-01-01 至 2026-07-27，threads=3，throttle=8，max_retries=3，batch_size=800000
# 2026-07-27 17:50:50 [ INFO  ] worker.py | run: 224行| <FundDailyWorker> 开始更新：2010-01-01 至 2026-07-27，字段=9，线程=3，限速=8次/秒，批量=800,000行
# 2026-07-27 17:50:50 [ INFO  ] stock.py | fetch_all: 224行| <FundDailyWorker> 覆盖计划：首次=73，续更=0，已最新=0，待请求=73/73，实际起点=2010-01-01 至 2010-01-01，截止=2026-07-27
# 2026-07-27 17:50:51 [ INFO  ] paginate.py | fetch: 199行| <FundDailyWorker>[512100.SH].fund_daily 分页完成：请求=2，有效页=2，原始行=2,361，补齐行=361，停止=短页，耗时=0.58秒
# 2026-07-27 17:50:51 [ INFO  ] paginate.py | fetch: 199行| <FundDailyWorker>[510500.SH].fund_daily 分页完成：请求=2，有效页=2，原始行=3,245，补齐行=1,245，停止=短页，耗时=0.66秒
# 2026-07-27 17:50:51 [ INFO  ] paginate.py | fetch: 199行| <FundDailyWorker>[510300.SH].fund_daily 分页完成：请求=2，有效页=2，原始行=3,442，补齐行=1,442，停止=短页，耗时=0.73秒
# ...

# %%
FundAdjFactorWorker(start_date=start_date, overwrite=True).run()
# Out:
# 2026-07-27 17:51:05 [ DEBUG ] stock.py | __init__: 80行| <FundAdjFactorWorker> 初始化：股票=73，2010-01-01 至 2026-07-27，threads=3，throttle=8，max_retries=3，batch_size=800000
# 2026-07-27 17:51:05 [ INFO  ] worker.py | run: 224行| <FundAdjFactorWorker> 开始更新：2010-01-01 至 2026-07-27，字段=1，线程=3，限速=8次/秒，批量=800,000行
# 2026-07-27 17:51:05 [ INFO  ] stock.py | fetch_all: 224行| <FundAdjFactorWorker> 覆盖计划：首次=73，续更=0，已最新=0，待请求=73/73，实际起点=2010-01-01 至 2010-01-01，截止=2026-07-27
# 2026-07-27 17:51:05 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512100.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,362，补齐行=362，停止=短页，耗时=0.19秒
# 2026-07-27 17:51:05 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510500.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,247，补齐行=1,247，停止=短页，耗时=0.21秒
# 2026-07-27 17:51:05 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510300.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,442，补齐行=1,442，停止=短页，耗时=0.24秒
# ...
