# %%
from core.workers import *
# Out:
# 2026-07-24 21:50:34 [SUCCESS] ts_api.py | <module>: 49行| Tushare Pro 初始化完成，共加载 5,869 只股票
# 2026-07-24 21:50:35 [ INFO  ] session.py | <module>: 10行| DolphinDB: 127.0.0.1:8848

# %%
start_date = "20100101"

# %%
StockDailyWorker(start_date=start_date).run()

# %%
StockLimitWorker(start_date=start_date).run()

# %%
StockDailyBasicWorker(start_date=start_date).run()

# %%
StockAdjFactorWorker(start_date=start_date).run()

# %%
StockHfqWorker(start_date=start_date).run()

# %%
StockBalanceSheetWorker(start_date=start_date).run()

# %%
StockIncomeWorker(start_date=start_date).run()

# %%
StockCashflowWorker(start_date=start_date).run()

# %%
StockFinaIndicatorWorker(start_date=start_date).run()

# %%
StockSTWorker(start_date=start_date).run()

# %%
IndexWeightWorker("000016.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000300.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000905.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000852.SH", start_date=start_date).run()

# %%
StockDividendWorker(start_date=start_date, overwrite=True).run()
# Out:
# 2026-07-24 21:50:37 [ DEBUG ] stock.py | __init__: 80行| <StockDividendWorker> 初始化：股票=5,869，2010-01-01 至 2026-07-24，threads=3，throttle=8，max_retries=3，batch_size=800000
# 2026-07-24 21:50:37 [ INFO  ] worker.py | run: 224行| <StockDividendWorker> 开始更新：2010-01-01 至 2026-07-24，字段=13，线程=3，限速=8次/秒，批量=800,000行
# 2026-07-24 21:50:37 [ DEBUG ] wide.py | open: 39行| <StockDividendWorker> 自定义表 Writer 已创建
# 2026-07-24 21:50:37 [ INFO  ] stock.py | fetch_all: 224行| <StockDividendWorker> 覆盖计划：首次=5,869，续更=0，已最新=0，待请求=5,869/5,869，实际起点=2010-01-01 至 2010-01-01，截止=2026-07-24
# 2026-07-24 21:50:39 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000035.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:50:43 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000155.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:50:45 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000410.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:50:49 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000520.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:50:49 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000523.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:50:56 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000595.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:51:04 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000703.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:51:08 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000751.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:51:11 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000792.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:51:20 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000912.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:51:22 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000935.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:51:26 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000972.SZ] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:51:26 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000980.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:51:50 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002072.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:51:57 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002131.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:02 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002175.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:04 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002192.SZ] 忽略 3 条日期不完整的分红记录
# 2026-07-24 21:52:06 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002204.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:06 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002210.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:23 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002354.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:34 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002445.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:40 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002501.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:52:53 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002608.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:53:05 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002716.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:53:43 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[300008.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:53:53 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[300099.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:56:52 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600176.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:13 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600399.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:25 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600537.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:31 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600602.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:33 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600626.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:40 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600699.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:50 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600785.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 21:57:55 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600828.SH] 忽略 2 条日期不完整的分红记录
# 2026-07-24 21:58:09 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[601005.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:19 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[000982.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:21 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[002260.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:27 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[300116.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:30 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[300362.SZ] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:34 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600145.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:39 [WARNING] stock_dividend.py | fetch_one: 92行| <StockDividendWorker>[600485.SH] 忽略 1 条日期不完整的分红记录
# 2026-07-24 22:02:50 [ INFO  ] stock.py | fetch_all: 324行| <StockDividendWorker> 获取汇总：状态=完成，任务=5,869，非空=5,590，空=279，结果行=47,470，失败=0，耗时=732.74秒
# 2026-07-24 22:02:50 [ DEBUG ] worker.py | write: 206行| <StockDividendWorker> 写入批次 1/1：提交=47,470行，实际写入=47,470行，本次累计=47,470行
# 2026-07-24 22:02:50 [SUCCESS] worker.py | run: 269行| <StockDividendWorker> 更新完成：写入=47,470行，耗时=733.29秒，吞吐=65行/秒
# 47470
