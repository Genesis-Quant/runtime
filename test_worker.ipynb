# %%
import pandas as pd

from core.workers import *

# %%
res = []
for i in StockCashflowWorker(("000001.SZ", "000002.SZ"), start_date="20160101", end_date="20170101").fetch_all():
    res.append(i)

pd.concat(res)
# Out:
#           time       code                   factor         value
# 0   2016-08-12  000001.SZ    amort_intang_assets_2  2.850000e+08
# 1   2016-03-10  000001.SZ    amort_intang_assets_4  6.230000e+08
# 2   2016-03-10  000001.SZ  amort_intang_assets_ttm  6.230000e+08
# 3   2016-08-12  000001.SZ  amort_intang_assets_ttm  6.020000e+08
# 4   2016-08-12  000001.SZ           beg_bal_cash_2  4.119000e+09
# ..         ...        ...                      ...           ...
# 343 2016-03-14  000002.SZ       stot_out_inv_act_4  2.459315e+10
# 344 2016-03-14  000002.SZ     stot_out_inv_act_ttm  2.459315e+10
# 345 2016-04-28  000002.SZ     stot_out_inv_act_ttm  2.826073e+10
# 346 2016-08-22  000002.SZ     stot_out_inv_act_ttm  3.972656e+10
# 347 2016-10-28  000002.SZ     stot_out_inv_act_ttm  4.715469e+10
#
# [660 rows x 4 columns]
