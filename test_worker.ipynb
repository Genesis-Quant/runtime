# %%
from core.workers import *

# %%
start_date = "20100101"

# %%
StockDailyWorker(start_date=start_date).run()

# %%
StockLimitWorker(start_date=start_date).run()

# %%
StockDailyBasicWorker(start_date=start_date).run()

# %%
StockAdjFactorWorker(start_date=start_date).run()

# %%
StockHfqWorker(start_date=start_date).run()

# %%
StockBalanceSheetWorker(start_date=start_date).run()

# %%
StockIncomeWorker(start_date=start_date).run()

# %%
StockCashflowWorker(start_date=start_date).run()

# %%
StockFinaIndicatorWorker(start_date=start_date).run()

# %%
StockSTWorker(start_date=start_date).run()

# %%
IndexWeightWorker("000016.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000300.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000905.SH", start_date=start_date).run()

# %%
IndexWeightWorker("000852.SH", start_date=start_date).run()

# %%
StockDividendWorker(start_date=start_date).run()

# %%
FundDailyWorker(start_date=start_date, overwrite=True).run()
# Out:
# 2026-07-27 21:48:29 [ INFO  ] paginate.py | fetch: 199行| <FundDailyWorker>[513500.SH].fund_daily 分页完成：请求=2，有效页=2，原始行=3,044，补齐行=1,044，停止=短页，耗时=0.37秒
# 2026-07-27 21:48:30 [ INFO  ] paginate.py | fetch: 199行| <FundDailyWorker>[513030.SH].fund_daily 分页完成：请求=2，有效页=2，原始行=2,886，补齐行=886，停止=短页，耗时=0.44秒
# 2026-07-27 21:48:31 [ INFO  ] stock.py | fetch_all: 324行| <FundDailyWorker> 获取汇总：状态=完成，任务=73，非空=73，空=0，结果行=1,161,108，失败=0，分页完成=73，多页=25，请求=102，有效页=102，返回行=129,012，补齐行=24,711，耗时=12.52秒
# 2026-07-27 21:48:31 [ DEBUG ] worker.py | write: 206行| <FundDailyWorker> 写入批次 1/1：提交=354,123行，实际写入=354,123行，本次累计=354,123行
# 2026-07-27 21:48:32 [SUCCESS] worker.py | run: 269行| <FundDailyWorker> 更新完成：写入=1,161,108行，耗时=13.81秒，吞吐=84,092行/秒
# 1161108

# %%
FundAdjFactorWorker(start_date=start_date, overwrite=True).run()
# Out:
# 2026-07-27 21:48:32 [ DEBUG ] stock.py | __init__: 80行| <FundAdjFactorWorker> 初始化：股票=73，2010-01-01 至 2026-07-27，threads=3，throttle=8，max_retries=3，batch_size=800000
# 2026-07-27 21:48:32 [ INFO  ] worker.py | run: 224行| <FundAdjFactorWorker> 开始更新：2010-01-01 至 2026-07-27，字段=1，线程=3，限速=8次/秒，批量=800,000行
# 2026-07-27 21:48:32 [ INFO  ] stock.py | fetch_all: 224行| <FundAdjFactorWorker> 覆盖计划：首次=73，续更=0，已最新=0，待请求=73/73，实际起点=2010-01-01 至 2010-01-01，截止=2026-07-27
# 2026-07-27 21:48:32 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512100.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,362，补齐行=362，停止=短页，耗时=0.29秒
# 2026-07-27 21:48:32 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510500.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,247，补齐行=1,247，停止=短页，耗时=0.31秒
# 2026-07-27 21:48:32 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510300.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,442，补齐行=1,442，停止=短页，耗时=0.32秒
# 2026-07-27 21:48:33 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510210.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,726，补齐行=1,726，停止=短页，耗时=0.30秒
# 2026-07-27 21:48:33 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510050.SH].fund_adj 分页完成：请求=3，有效页=3，原始行=4,021，补齐行=2,021，停止=短页，耗时=0.62秒
# 2026-07-27 21:48:33 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[159949.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=2,430，补齐行=430，停止=短页，耗时=0.31秒
# 2026-07-27 21:48:34 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510180.SH].fund_adj 分页完成：请求=3，有效页=3，原始行=4,021，补齐行=2,021，停止=短页，耗时=1.07秒
# 2026-07-27 21:48:34 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[159915.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=3,551，补齐行=1,551，停止=短页，耗时=0.61秒
# 2026-07-27 21:48:34 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[159901.SZ].fund_adj 分页完成：请求=3，有效页=3，原始行=4,021，补齐行=2,021，停止=短页，耗时=1.20秒
# 2026-07-27 21:48:35 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[159928.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=3,124，补齐行=1,124，停止=短页，耗时=0.88秒
# 2026-07-27 21:48:36 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512400.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,158，补齐行=158，停止=短页，耗时=0.77秒
# 2026-07-27 21:48:36 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512200.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,142，补齐行=142，停止=短页，耗时=0.69秒
# 2026-07-27 21:48:36 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512660.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,419，补齐行=419，停止=短页，耗时=0.38秒
# 2026-07-27 21:48:37 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512880.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,419，补齐行=419，停止=短页，耗时=0.89秒
# 2026-07-27 21:48:37 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512800.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,179，补齐行=179，停止=短页，耗时=1.09秒
# 2026-07-27 21:48:38 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[512980.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,064，补齐行=64，停止=短页，耗时=0.44秒
# 2026-07-27 21:48:39 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[510880.SH].fund_adj 分页完成：请求=3，有效页=3，原始行=4,021，补齐行=2,021，停止=短页，耗时=0.76秒
# 2026-07-27 21:48:40 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[518880.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,159，补齐行=1,159，停止=短页，耗时=0.48秒
# 2026-07-27 21:48:40 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[501018.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,448，补齐行=448，停止=短页，耗时=1.01秒
# 2026-07-27 21:48:41 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[161226.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=2,657，补齐行=657，停止=短页，耗时=0.64秒
# 2026-07-27 21:48:41 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[159920.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=3,343，补齐行=1,343，停止=短页，耗时=0.84秒
# 2026-07-27 21:48:42 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[159941.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=2,682，补齐行=682，停止=短页，耗时=0.40秒
# 2026-07-27 21:48:42 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[513500.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,045，补齐行=1,045，停止=短页，耗时=0.51秒
# 2026-07-27 21:48:42 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[513100.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=3,209，补齐行=1,209，停止=短页，耗时=0.99秒
# 2026-07-27 21:48:43 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[513030.SH].fund_adj 分页完成：请求=2，有效页=2，原始行=2,887，补齐行=887，停止=短页，耗时=0.74秒
# 2026-07-27 21:48:44 [ INFO  ] paginate.py | fetch: 199行| <FundAdjFactorWorker>[160644.SZ].fund_adj 分页完成：请求=2，有效页=2，原始行=2,077，补齐行=77，停止=短页，耗时=0.48秒
# 2026-07-27 21:48:44 [ INFO  ] stock.py | fetch_all: 324行| <FundAdjFactorWorker> 获取汇总：状态=完成，任务=73，非空=73，空=0，结果行=129,301，失败=0，分页完成=73，多页=26，请求=103，有效页=103，返回行=129,301，补齐行=24,854，耗时=12.00秒
# 2026-07-27 21:48:44 [ DEBUG ] core.py | open: 209行| DolphinDB Writer 已创建：threads=1，factor=1 个
# 2026-07-27 21:48:44 [ DEBUG ] worker.py | write: 206行| <FundAdjFactorWorker> 写入批次 1/1：提交=129,301行，实际写入=129,301行，本次累计=129,301行
# 2026-07-27 21:48:45 [SUCCESS] worker.py | run: 269行| <FundAdjFactorWorker> 更新完成：写入=129,301行，耗时=13.28秒，吞吐=9,737行/秒
# 129301
